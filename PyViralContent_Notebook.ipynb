# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaskatripathi/pyviralcontent/blob/main/PyViralContent_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyviralcontent
# Out:
# Collecting pyviralcontent
#   Downloading pyviralcontent-0.1.2-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyviralcontent) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyviralcontent) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyviralcontent) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from pyviralcontent) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyviralcontent) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyviralcontent) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pyviralcontent) (1.16.0)
# Installing collected packages: pyviralcontent
# Successfully installed pyviralcontent-0.1.2

# %% [markdown]
# **Supported Content Types**
#
# The package currently supports the following content types:
#
# - scientific
# - blog
# - video
# - technical
# - fictional
# - legal
# - educational
# - news
# - advertising
# - social_media

# %%
from pyviralcontent import ContentAnalyzer

def test_content_analysis(content_type, text_content):
    """
    Test the content analysis for a given type of content and text content.

    :param content_type: The type of the content (e.g., 'scientific', 'blog', etc.).
    :param text_content: The actual content to analyze.
    """
    # Create an instance of ContentAnalyzer
    analyzer = ContentAnalyzer(text_content, content_type)
    # Perform the analysis
    df, viral_probability = analyzer.analyze()
    # Print the results
    print(f"\nReadability Scores Summary for {content_type.capitalize()} Content:")
    display(df)
    print(f"The probability of the content going viral is: {viral_probability * 100:.2f}%")

# Example 1: Scientific content
test_content_analysis(
    'scientific',
    "Implement an accessibility-first approach in the design of the website. This includes: • High-contrast visuals for low-vision users. • Text-to-speech functionality for all text, including product descriptions and checkout processes.• Easy keyboard navigation for those unable to use a mouse."
)

# Example 2: Blog content
test_content_analysis(
    'blog',
    "Today's blog post discusses the importance of user experience design. A good design ensures that users find joy and satisfaction in the interaction with the product, making it an essential aspect of product development."
)

# Example 3: Technical content
test_content_analysis(
    'technical',
    "The module utilizes an advanced algorithm for data processing, ensuring high performance and reliability. It's optimized for multi-threaded environments, offering significant improvements in processing speed and efficiency."
)

# Example 4: Fictional content
test_content_analysis(
    'fictional',
    "In the distant future, humanity has reached the stars. Each galaxy is a new frontier, and every planet a new adventure. Join our heroes as they navigate through cosmic dangers and discover the mysteries of the universe."
)

# Example 5: Legal content
test_content_analysis(
    'legal',
    "The contract stipulates the terms and conditions of the agreement and is legally binding to both parties involved. It outlines the responsibilities, duties, and liabilities in clear, unambiguous language to prevent any misunderstandings."
)

# Example 6: Educational content
test_content_analysis(
    'educational',
    "Today's lesson covers the fundamental principles of physics. We'll explore Newton's laws of motion, the concept of gravity, and the principles of energy and momentum. Each concept will be demonstrated with real-life examples and interactive experiments."
)

# Example 7: News content
test_content_analysis(
    'news',
    "In today's news, the local community is coming together to support the annual food drive. Last year's drive helped over a thousand families, and this year the organizers hope to double that number with the help of generous donations and volunteer work."
)

# Example 8: Advertising content
test_content_analysis(
    'advertising',
    "Introducing the latest innovation in home cleaning! Our new vacuum cleaner is equipped with advanced technology to clean your home efficiently and effortlessly. Say goodbye to dust and hello to spotless floors!"
)

# Example 9: Social Media content
test_content_analysis(
    'social_media',
    "Just finished an amazing workout at the gym! 💪 Feeling energized and ready to take on the day. Remember, a healthy lifestyle is not just a goal, it's a way of living. #FitnessGoals #HealthyLiving"
)

# Example 10: Video content
test_content_analysis(
    'video',
    "In this video, we'll take a closer look at the intricate ecosystem of the Amazon rainforest. Discover the diverse species that call it home, and learn about the critical role it plays in our planet's climate system."
)
# Out:
# Readability Scores Summary for Scientific Content:
#             Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0    gunning_fog  15.200000             2  Below Average/Confusing
# 1   coleman_liau  17.544000             1             Poor/Unclear
# 2            ari  12.243000             1             Poor/Unclear
# 3  OVERALL SCORE  14.995667             1             Poor/Unclear
#
#    Weighted_Likert
# 0              0.2
# 1              0.2
# 2              0.2
# 3              0.0
# The probability of the content going viral is: 24.00%
# Readability Scores Summary for Blog Content:
#                   Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0  flesch_reading_ease  41.061078             2  Below Average/Confusing
# 1       flesch_kincaid  10.347647             1             Poor/Unclear
# 2        OVERALL SCORE  25.704363             1             Poor/Unclear
#
#    Weighted_Likert
# 0             0.30
# 1             0.15
# 2             0.00
# The probability of the content going viral is: 30.00%
# Readability Scores Summary for Technical Content:
#             Test      Score  Likert_Scale Qualitative_Descriptors  \
# 0  linsear_write  19.000000             1            Poor/Unclear
# 1            ari  17.435556             1            Poor/Unclear
# 2  OVERALL SCORE  18.217778             1            Poor/Unclear
#
#    Weighted_Likert
# 0              0.1
# 1              0.2
# 2              0.0
# The probability of the content going viral is: 20.00%
# Readability Scores Summary for Fictional Content:
#              Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0  flesch_kincaid   8.747230             2  Below Average/Confusing
# 1    coleman_liau  10.082162             3   Average/Somewhat Clear
# 2   OVERALL SCORE   9.414696             1             Poor/Unclear
#
#    Weighted_Likert
# 0              0.3
# 1              0.6
# 2              0.0
# The probability of the content going viral is: 51.43%
# Readability Scores Summary for Legal Content:
#             Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0    gunning_fog  16.521212             2  Below Average/Confusing
# 1           smog  13.559100             2  Below Average/Confusing
# 2  OVERALL SCORE  15.040156             1             Poor/Unclear
#
#    Weighted_Likert
# 0              0.2
# 1              0.2
# 2              0.0
# The probability of the content going viral is: 40.00%
# Readability Scores Summary for Educational Content:
#              Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0  flesch_kincaid  10.864444             1             Poor/Unclear
# 1   linsear_write  14.000000             2  Below Average/Confusing
# 2   OVERALL SCORE  12.432222             1             Poor/Unclear
#
#    Weighted_Likert
# 0             0.15
# 1             0.20
# 2             0.00
# The probability of the content going viral is: 28.00%
# Readability Scores Summary for News Content:
#                   Test      Score  Likert_Scale  Qualitative_Descriptors  \
# 0  flesch_reading_ease  55.653571             3   Average/Somewhat Clear
# 1          gunning_fog  12.266667             2  Below Average/Confusing
# 2        OVERALL SCORE  33.960119             1             Poor/Unclear
#
#    Weighted_Likert
# 0             0.45
# 1             0.20
# 2             0.00
# The probability of the content going viral is: 52.00%
# Readability Scores Summary for Advertising Content:
#                   Test     Score  Likert_Scale  Qualitative_Descriptors  \
# 0  flesch_reading_ease  39.90125             2  Below Average/Confusing
# 1         coleman_liau  15.24125             1             Poor/Unclear
# 2        OVERALL SCORE  27.57125             1             Poor/Unclear
#
#    Weighted_Likert
# 0              0.3
# 1              0.2
# 2              0.0
# The probability of the content going viral is: 28.57%
# Readability Scores Summary for Social_media Content:
#                   Test      Score  Likert_Scale Qualitative_Descriptors  \
# 0  flesch_reading_ease  58.478725             3  Average/Somewhat Clear
# 1        linsear_write  16.000000             1            Poor/Unclear
# 2        OVERALL SCORE  37.239363             1            Poor/Unclear
#
#    Weighted_Likert
# 0             0.45
# 1             0.10
# 2             0.00
# The probability of the content going viral is: 44.00%
# Readability Scores Summary for Video Content:
#                   Test      Score  Likert_Scale Qualitative_Descriptors  \
# 0  flesch_reading_ease  59.413964             3  Average/Somewhat Clear
# 1                 smog  11.208143             3  Average/Somewhat Clear
# 2        OVERALL SCORE  35.311054             1            Poor/Unclear
#
#    Weighted_Likert
# 0             0.45
# 1             0.30
# 2             0.00
# The probability of the content going viral is: 60.00%
